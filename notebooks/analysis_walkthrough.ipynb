# %% [markdown]
# # Engagement Collapse RCA Walkthrough
#
# This notebook is intentionally lightweight. The reproducible source of truth is the scripts and SQL files:
#
# 1. `python scripts/generate_synthetic_data.py`
# 2. `python scripts/validate_data.py`
# 3. `python scripts/run_analysis.py`
#
# Use the generated files in `reports/` and `data/processed/` for review.

# %%
import json
from pathlib import Path

summary = json.loads(Path('../reports/analysis_summary.json').read_text())
summary
